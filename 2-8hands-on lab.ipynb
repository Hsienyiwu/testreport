# %%
# !pip install yfinance
# !pip install bs4
# !pip install nbformat
# !pip install pandas
# !pip install requests
# !pip install html5lib
# !pip install plt
# !pip install matplotlib
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement plt (from versions: none)
# ERROR: No matching distribution found for plt
# ...

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# 步驟1：下載特斯拉股票數據
tesla_data = yf.download('TSLA', start='2020-01-01', end='2023-01-01')

# 步驟2：創建收入數據（如果沒有現有的收入數據文件）
# 這裡手動創建收入數據作為示例
tesla_revenue = pd.DataFrame({
    'Date': ['2020-01-01', '2020-04-01', '2020-07-01', '2020-10-01', '2021-01-01'],
    'Revenue': [7350, 8430, 10450, 10750, 10750]
})

# 確保日期列的格式正確
tesla_data.reset_index(inplace=True)  # 將索引重置為列
tesla_data['Date'] = pd.to_datetime(tesla_data['Date'])
tesla_revenue['Date'] = pd.to_datetime(tesla_revenue['Date'])

# 重置索引
tesla_data.reset_index(inplace=True, drop=True)
tesla_revenue.reset_index(inplace=True, drop=True)

# 步驟3：定義 make_graph 函數
def make_graph(stock_data, revenue_data, company_name):
    fig, ax1 = plt.subplots()

    # 畫股票價格
    ax1.plot(stock_data['Date'], stock_data['Close'], 'b-')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Stock Price', color='b')

    # 創建第二個 y 軸來畫收入數據
    ax2 = ax1.twinx()
    ax2.plot(revenue_data['Date'], revenue_data['Revenue'], 'r-')
    ax2.set_ylabel('Revenue', color='r')

    plt.title(f'{company_name} Stock Price and Revenue')
    plt.show()

# 步驟4：繪製特斯拉股票圖
make_graph(tesla_data, tesla_revenue, 'Tesla')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# 步驟1：下載GME股票數據
gamestop_data = yf.download('GME', start='2022-01-01', end='2024-01-01')
# 步驟2：創建收入數據（如果沒有現有的收入數據文件）
# 這裡手動創建收入數據作為示例
gamestop_revenue = pd.DataFrame({
    'Date': ['2022-01-01', '2022-04-01', '2022-07-01', '2022-10-01', '2023-01-01'],
    'Revenue': [7350, 8430, 10450, 10750, 10750]
})
# 確保日期列的格式正確
gamestop_data.reset_index(inplace=True)  # 將索引重置為列
gamestop_data['Date'] = pd.to_datetime(gamestop_data['Date'])
gamestop_revenue['Date'] = pd.to_datetime(gamestop_revenue['Date'])
# 重置索引
gamestop_data.reset_index(inplace=True, drop=True)
gamestop_revenue.reset_index(inplace=True, drop=True)
# 步驟3：定義 make_graph 函數
def make_graph(stock_data, revenue_data, company_name):
    fig, ax1 = plt.subplots()
    # 畫股票價格
    ax1.plot(stock_data['Date'], stock_data['Close'], 'b-')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Stock Price', color='b')
    # 創建第二個 y 軸來畫收入數據
    ax2 = ax1.twinx()
    ax2.plot(revenue_data['Date'], revenue_data['Revenue'], 'r-')
    ax2.set_ylabel('Revenue', color='r')

    plt.title(f'{company_name} Stock Price and Revenue')
    plt.show()
# 步驟4：繪製GME股票圖
make_graph(gamestop_data, gamestop_revenue, 'gamestop')
# Out:
# [*********************100%%**********************]  1 of 1 completed
